# %% [markdown]
# Create Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
data = {
    'Math_Score': np.random.randint(50, 100, 25),
    'English_Score': np.random.randint(45, 95, 25),
    'Science_Score': np.random.randint(40, 100, 25),
    'Attendance (%)': np.random.randint(70, 100, 25),
    'Study_Hours_per_Week': np.random.randint(5, 25, 25)
}
df = pd.DataFrame(data)
print("Original Student Dataset:\n")
df
# Out:
# Original Student Dataset:
#     Math_Score  English_Score  Science_Score  Attendance (%)  \
# 0           88             56             92              95
# 1           78             66             41              81
# 2           64             88             59              71
# 3           92             69             67              79
# 4           57             93             86              99
# 5           70             71             99              73
# 6           88             86             46              83
# 7           68             72             83              85
# 8           72             60             47              84
# 9           60             59             86              77
# 10          60             91             74              83
# 11          73             88             53              92
# 12          85             47             56              97
# 13          89             81             75              94
# ...

# %%
df.describe()
# Out:
#        Math_Score  English_Score  Science_Score  Attendance (%)  \
# count   25.000000      25.000000      25.000000       25.000000
# mean    73.040000      69.320000      67.840000       86.760000
# std     13.039939      14.935193      19.588857        7.975379
# min     51.000000      47.000000      41.000000       71.000000
# 25%     64.000000      58.000000      47.000000       82.000000
# 50%     73.000000      69.000000      68.000000       85.000000
# 75%     85.000000      83.000000      86.000000       94.000000
# max     93.000000      94.000000      99.000000       99.000000
#
#        Study_Hours_per_Week
# count             25.000000
# mean              12.680000
# std                4.775982
# min                5.000000
# 25%               11.000000
# 50%               13.000000
# 75%               16.000000
# max               23.000000

# %%
print("\nRange of Each Feature:\n")
for column in df.columns:
    print(f"{column}: min = {df[column].min():.2f}, max = {df[column].max():.2f}")
# Out:
# Range of Each Feature:
#
# Math_Score: min = 51.00, max = 93.00
# English_Score: min = 47.00, max = 94.00
# Science_Score: min = 41.00, max = 99.00
# Attendance (%): min = 71.00, max = 99.00
# Study_Hours_per_Week: min = 5.00, max = 23.00

# %% [markdown]
# Data Normalization

# %%
normalized_df = df.copy()
for column in normalized_df.columns:
    mean = normalized_df[column].mean()
    std = normalized_df[column].std()
    normalized_df[column] = (normalized_df[column] - mean) / std
print("\nNormalized Student Dataset:\n")
normalized_df
# Out:
# Normalized Student Dataset:
#     Math_Score  English_Score  Science_Score  Attendance (%)  \
# 0     1.147245      -0.891853       1.233354        1.033180
# 1     0.380370      -0.222294      -1.370167       -0.722223
# 2    -0.693255       1.250737      -0.451277       -1.976082
# 3     1.453995      -0.021426      -0.042882       -0.972995
# 4    -1.230067       1.585517       0.927058        1.534723
# 5    -0.233130       0.112486       1.590700       -1.725310
# 6     1.147245       1.116825      -1.114920       -0.471451
# 7    -0.386505       0.179442       0.773909       -0.220679
# 8    -0.079755      -0.624029      -1.063870       -0.346065
# 9    -1.000005      -0.690985       0.927058       -1.223766
# 10   -1.000005       1.451605       0.314464       -0.471451
# 11   -0.003067       1.250737      -0.757574        0.657022
# 12    0.917182      -1.494457      -0.604425        1.283952
# 13    1.223932       0.782045       0.365514        0.907794
# ...

# %%
normalized_df.describe()
# Out:
#          Math_Score  English_Score  Science_Score  Attendance (%)  \
# count  2.500000e+01   2.500000e+01   2.500000e+01    2.500000e+01
# mean  -5.018208e-16   4.660161e-16  -1.598721e-16   -6.306067e-16
# std    1.000000e+00   1.000000e+00   1.000000e+00    1.000000e+00
# min   -1.690192e+00  -1.494457e+00  -1.370167e+00   -1.976082e+00
# 25%   -6.932548e-01  -7.579413e-01  -1.063870e+00   -5.968369e-01
# 50%   -3.067499e-03  -2.142590e-02   8.167909e-03   -2.206792e-01
# 75%    9.171822e-01   9.159573e-01   9.270576e-01    9.077939e-01
# max    1.530682e+00   1.652473e+00   1.590700e+00    1.534723e+00
#
#        Study_Hours_per_Week
# count          2.500000e+01
# mean           4.884981e-17
# std            1.000000e+00
# min           -1.608046e+00
# 25%           -3.517602e-01
# 50%            6.700193e-02
# 75%            6.951451e-01
# max            2.160812e+00

# %% [markdown]
# Show range of each feature

# %%
print("\nRange of Each Normalized Feature:\n")
for column in normalized_df.columns:
    print(f"{column}: min = {normalized_df[column].min():.2f}, max = {normalized_df[column].max():.2f}")
# Out:
# Range of Each Normalized Feature:
#
# Math_Score: min = -1.69, max = 1.53
# English_Score: min = -1.49, max = 1.65
# Science_Score: min = -1.37, max = 1.59
# Attendance (%): min = -1.98, max = 1.53
# Study_Hours_per_Week: min = -1.61, max = 2.16

# %% [markdown]
# Visualize the normalized data

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(normalized_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation (Normalized Data)")
plt.show()

# %% [markdown]
# Save normalized data

# %%
normalized_df.to_csv("normalized_student_data.csv", index=False)
print("\nNormalized dataset saved as 'normalized_student_data.csv'")
# Out:
# Normalized dataset saved as 'normalized_student_data.csv'
